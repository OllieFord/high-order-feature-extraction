# %% [markdown]
# # Collect and Clean data
# Data processing steps:
# 1. sentence pos_tagged
# 2. lemmatized
# 3. extracted stop words
# 4. retain only content words (nouns, verbs, adjectives, adverbs)
#
# Goal: each book is a collection of sentences that has had the above steps applied.

# %%
#remove gutenberg specifc noise : notes etc

# %%
#find meta data for each book: category('s), author, -- gutenberg library

# %%
#pos_tagging

# %%
#lematization

# %%
# stop word removal

# %%
#content words
